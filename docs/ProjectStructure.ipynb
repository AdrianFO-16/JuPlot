# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(60, 219, 61);
#     font-size: 60px;}
# </style>
#
#
# <h1> Ju-Plot</h1>

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
#
# <h1> Figure - Plot  Parts </h1>
#
#
# + Figure
#     + height
#     + weight
#     + dpi
#     + Paper
#         + Color
#     + Plot Background
#         + Grid
#         + Color
# + Backends
#     + Plotly
#     + Matplotlib
#         + Seaborn
#             + Latex Hab -> buscar forma de hacer que sea rapido
# + Type(s)
#     + scatter, line, boxplot etc.
#         + line, marker, fill
# + Data
#     + Representations, x,y,z, series. Interpreted by type of plot (pandas dataframe)
# + Title
#     + Font
#     + Position
# + Axes
#     + Ticks
#     + Labels
#         + Font
# + Legend
#     + Title
#     + Contents
#         + Font
# + Subplots (rec)
#     + Grid Layout (rows col)
#
#
# + Font
#     + Size
#     + Color
#     + Family
#     + Weight
#     + Decorations
#
# + Color Palette
#     + colors

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
#
# <h1> Frontend Functions </h1>
#
# + Plot
# + Show
# + Set Backend
# + Get Theme
# + Set Theme
# + Overwrite local attributes
# + Subplot
#
#
# <h1> Type of Plots ENUM or STATIC</h1>
# Sacar de Seaborn + Plotly

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
#
# <h1> Data Structures </h1>
#
#
# + Theme (Elements)
#     + font
#     + figure
#     + axes
#     + legend
#     + color palette
# + Plot Type (ENUM)

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
# <h1>TODO</h1>
#
# + Exception Desings

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
#
# <h1>Font data structure</h1>
#
#
# ```python
# TITLE_FONT = dict(
#
#           #"Arial", "Balto", "Courier New", "Droid Sans",, "Droid Serif",
#           #"Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans",
#           #"Overpass", "PT Sans Narrow", "Raleway", "Times New Roman".
#
#           # family = "Franklin Gothic",
#           size = 30,
#           color = "rgba(0,0,0,1)"
#         )
#
# FONT = dict(
#
#           #"Arial", "Balto", "Courier New", "Droid Sans",, "Droid Serif",
#           #"Droid Sans Mono", "Gravitas One", "Old Standard TT", "Open Sans",
#           #"Overpass", "PT Sans Narrow", "Raleway", "Times New Roman".
#
#           family = "Raleway",
#           size = 10,
#           color = "rgba(0,0,0,1)"
#         )
#
#
#
# PLOTLY_PARAMS = dict(
#
#     width = 1200,
#     height = 800,
#     paper_bgcolor = "rgba(0,0,0,0)",
#     plot_bgcolor = "rgba(0.2,0.2,0.2,0.2)",
#
#
#     title_font = TITLE_FONT,
#     font = FONT
#
#
# )
# ```

# %% [markdown]
# <style>
#     ul{
#     list-style-type: circle;
# }
#     li{margin-top: 7px}
#
#     li li {margin-top: 5px;}
#
#     h1{color: rgba(219, 90, 61);}
# </style>
#
# <h1>Order</h1>
#
# + Pyplot
# + Plotly
# + Seaborn
#
# + Configure
# + Plot
# + Show
